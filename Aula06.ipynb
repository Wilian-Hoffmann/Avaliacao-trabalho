# %%
import pandas as pd

# %%
estados = pd.read_csv('brasil_estados.csv')
estados
# Out:
#     Unnamed: 0                   uf  codigo         area  populacao  \
# 0            0                 Acre      12   164123.964     894470
# 1            1              Alagoas      27    27843.295    3351543
# 2            2                Amapá      16   142470.762     861773
# 3            3             Amazonas      13  1559167.889    4207714
# 4            4                Bahia      29   564760.427   14930634
# 5            5                Ceará      23   148894.441    9187103
# 6            6     Distrito Federal      53     5760.783    3055149
# 7            7       Espírito Santo      32    46074.447    4064052
# 8            8                Goiás      52   340203.329    7113540
# 9            9             Maranhão      21   329642.182    7114598
# 10          10          Mato Grosso      51   903207.019    3526220
# 11          11   Mato Grosso do Sul      50   357145.534    2809394
# 12          12         Minas Gerais      31   586521.123   21292666
# ...

# %%
data = estados[
    [
        'area',
        'populacao',
        'densidade',
        'matricula',
        'idh',
        'receitas',
        'despesas',
        'rendimento',
        'veiculos'
    ]
]

# %%
import seaborn as sns

# %%
sns.regplot(data=data, x='area', y='populacao')
# Out:
# <Axes: xlabel='area', ylabel='populacao'>
